# %%
import pandas_datareader as pdr

# %%
df=pdr.get_data_tiingo('AAPL', api_key="ba88ae6ced396ce7191ed6478f1a5c554b47d062")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df=pdr.get_data_tiingo('AAPL', api_key="ba88ae6ced396ce7191ed6478f1a5c554b47d062")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas_datareader\data.py:120, in get_data_tiingo(*args, **kwargs)
#     119 def get_data_tiingo(*args, **kwargs):
# --> 120     return TiingoDailyReader(*args, **kwargs).read()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas_datareader\tiingo.py:234, in TiingoDailyReader.read(self)
#     232     finally:
#     233         self.close()
# --> 234 return pd.concat(dfs, self._concat_axis)
#
# TypeError: concat() takes 1 positional argument but 2 were given

# %%
df.head()
# Out:
#                                    close    high     low    open    volume  \
# symbol date
# AAPL   2018-03-05 00:00:00+00:00  176.82  177.74  174.52  175.21  28401366
#        2018-03-06 00:00:00+00:00  176.67  178.25  176.13  177.91  23788506
#        2018-03-07 00:00:00+00:00  175.03  175.85  174.27  174.94  31703462
#        2018-03-08 00:00:00+00:00  176.94  177.12  175.07  175.48  23163767
#        2018-03-09 00:00:00+00:00  179.98  180.00  177.39  177.96  31385134
#
#                                    adjClose    adjHigh     adjLow    adjOpen  \
# symbol date
# AAPL   2018-03-05 00:00:00+00:00  42.084503  42.303470  41.537085  41.701310
#        2018-03-06 00:00:00+00:00  42.048801  42.424853  41.920277  42.343931
#        2018-03-07 00:00:00+00:00  41.658469  41.853635  41.477583  41.637048
#        2018-03-08 00:00:00+00:00  42.113063  42.155905  41.667989  41.765572
#        2018-03-09 00:00:00+00:00  42.836607  42.841367  42.220167  42.355831
#
# ...

# %%
df.to_csv('AAPL.csv')

# %%
df.head()
# Out:
#                                    close    high     low    open    volume  \
# symbol date
# AAPL   2018-03-05 00:00:00+00:00  176.82  177.74  174.52  175.21  28401366
#        2018-03-06 00:00:00+00:00  176.67  178.25  176.13  177.91  23788506
#        2018-03-07 00:00:00+00:00  175.03  175.85  174.27  174.94  31703462
#        2018-03-08 00:00:00+00:00  176.94  177.12  175.07  175.48  23163767
#        2018-03-09 00:00:00+00:00  179.98  180.00  177.39  177.96  31385134
#
#                                    adjClose    adjHigh     adjLow    adjOpen  \
# symbol date
# AAPL   2018-03-05 00:00:00+00:00  42.084503  42.303470  41.537085  41.701310
#        2018-03-06 00:00:00+00:00  42.048801  42.424853  41.920277  42.343931
#        2018-03-07 00:00:00+00:00  41.658469  41.853635  41.477583  41.637048
#        2018-03-08 00:00:00+00:00  42.113063  42.155905  41.667989  41.765572
#        2018-03-09 00:00:00+00:00  42.836607  42.841367  42.220167  42.355831
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('AAPL.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df=pd.read_csv('AAPL.csv')
#
# NameError: name 'pd' is not defined
